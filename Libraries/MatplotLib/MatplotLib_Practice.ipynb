# %%
from matplotlib import pyplot
x1 = [1,3,4,5]
y1 = [3,2,1,4]
x2 = [1,3,3,8]
y2 = [3,1,0,3]
pyplot.plot(x1,y1,label='car')
pyplot.plot(x2,y2,label='bike')
pyplot.legend()
pyplot.ylabel('y - axis')
pyplot.xlabel('x - axis')
# Out:
# Text(0.5,0,'x - axis')
