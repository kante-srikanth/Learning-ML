# %%
#RELPLOT

# %%
import seaborn as sns
sns.get_dataset_names()
data = sns.load_dataset("flights")
sns.relplot(x="month",y="passengers",hue="month",data=data)

# %%
import seaborn as sns
a = pd.DataFrame({'Day':[1,2,3,4,5,6,7],'Grocery':[30,80,45,23,51,46,76],'Clothes':[13,40,34,23,54,67,98],'Utensils':[12,32,27,56,87,54,34]},index=[1,2,3,4,5,6,7])
g = sns.relplot(x="Day",y="Clothes",data=a,kind="line")
g.fig.autofmt_xdate()

# %%
data = sns.load_dataset("tips")
data.head()
sns.relplot(x="day",y="total_bill",data=data)

# %%
from matplotlib import pyplot as plt
import seaborn as  sns
data = sns.load_dataset("tips")
x = data.day
y = data.total_bill
sns.catplot(x="day",y="total_bill",data=data)

# %%
sns.catplot(x="day",y="total_bill",data=data,kind="violin")

# %%
import numpy as np
x = np.random.normal(loc=5,size=100,scale=2)
y = np.random.normal(loc=5,size=100,scale=1)
sns.distplot(x,color="black")

# %%
sns.distplot(y,color="green")

# %%
sns.jointplot(x=x,y=y,color="red",kind="kde")

# %%
iris_data = sns.load_dataset("iris")
iris_data.head(5)
b=sns.FacetGrid(iris_data,col="species")
b.map(plt.hist,"sepal_length")

# %%
x=iris_data.sepal_length
sns.distplot(x)

# %%
sns.set(style="ticks")
b=sns.PairGrid(iris_data)
b.map(plt.scatter)

# %%
data = sns.load_dataset("tips")
sns.boxplot(x="day",y="total_bill",data=data)
sns.despine()

# %%
sns.set(style="darkgrid")
x = data.total_bill
sns.distplot(x)

# %%
palette = sns.color_palette()
sns.palplot(palette)
