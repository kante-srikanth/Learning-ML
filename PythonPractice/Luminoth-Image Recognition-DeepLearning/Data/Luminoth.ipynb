# %%
# !lumi dataset transform \
      --type openimages \
      --data-dir . \
      --output-dir ./out \
      --split train  \
      --class-examples 100 \
      --only-classes=/m/015qff,/m/0199g,/m/01bjv,/m/01g317,/m/04_sv,/m/07r04,/m/0h2r6,/m/0k4j
# Out:
# INFO:tensorflow:Saving split "train" in output_dir = ./out
#   [------------------------------------]    0%2019-02-17 09:01:56.934329: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing config loader against fileName /Users/kants2//.aws/config and using profilePrefix = 1
# 2019-02-17 09:01:56.934442: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing config loader against fileName /Users/kants2//.aws/credentials and using profilePrefix = 0
# 2019-02-17 09:01:56.934489: I tensorflow/core/platform/s3/aws_logging.cc:54] Setting provider to read credentials from /Users/kants2//.aws/credentials for credentials file and /Users/kants2//.aws/config for the config file , for use with profile default
# 2019-02-17 09:01:56.934623: I tensorflow/core/platform/s3/aws_logging.cc:54] Creating HttpClient with max connections2 and scheme http
# 2019-02-17 09:01:56.935022: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing CurlHandleContainer with size 2
# ...

# %%
# !lumi train -c config.yml
# Out:
# WARNING:tensorflow:From /Users/kants2/anaconda3/lib/python3.6/site-packages/luminoth/datasets/base_dataset.py:44: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /Users/kants2/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/input.py:276: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# ...

# %%
tensorboard --logdir .sampleDemo/traffic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-031c0de98805> in <module>
# ----> 1 tensorboard --logdir .sampleDemo/traffic
#
# NameError: name 'tensorboard' is not defined

# %%
# !pip install keras
# Out:
# ...
#     100% |████████████████████████████████| 317kB 10.6MB/s ta 0:00:01
# ...
# You are using pip version 19.0.1, however version 19.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install --upgrade pip
# Out:
# ...
#     100% |████████████████████████████████| 1.4MB 17.3MB/s ta 0:00:01
# ...
#   Found existing installation: pip 19.0.1
#     Uninstalling pip-19.0.1:
#       Successfully uninstalled pip-19.0.1
# ...

# %%
# !pip install keras
from keras.callbacks import TensorBoard
# Out:
# ...
# Using TensorFlow backend.

# %%
# !tensorboard --logdir sampleDemo/traffic
# Out:
# W0217 11:06:47.774079 Reloader tf_logging.py:120] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0217 11:06:47.774079 123145545498624 tf_logging.py:120] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0217 11:06:47.795091 Reloader tf_logging.py:120] Found more than one metagraph event per run. Overwriting the metagraph with the newest event.
# W0217 11:06:47.795091 123145545498624 tf_logging.py:120] Found more than one metagraph event per run. Overwriting the metagraph with the newest event.
# TensorBoard 1.12.0 at http://l34551oin.rpega.com:6006 (Press CTRL+C to quit)

# %%
# !lumi server web -c config.yml

# %%
# !lumi server web -c config.yml
